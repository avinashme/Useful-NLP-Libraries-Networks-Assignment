# %% [markdown]
# # Useful NLP Libraries & Networks | Assignment
#
# **Submission Notebook**

# %% [markdown]
# ## Question 1
#
# **Compare and contrast NLTK and spaCy in terms of features, ease of use, and performance.**

# %% [markdown]
# ### Answer

# %% [markdown]
# ## Question 2
#
# **What is TextBlob and how does it simplify common NLP tasks like sentiment analysis and translation?**

# %% [markdown]
# ### Answer

# %% [markdown]
# ## Question 3
#
# **Explain the role of Stanford NLP in academic and industry NLP Projects.**

# %% [markdown]
# ### Answer

# %% [markdown]
# ## Question 4
#
# **Describe the architecture and functioning of a Recurrent Neural Network (RNN).**

# %% [markdown]
# ### Answer

# %% [markdown]
# ## Question 5
#
# **What is the key difference between LSTM and GRU networks in NLP applications?**

# %% [markdown]
# ### Answer

# %% [markdown]
# ## Question 6
#
# **Write a Python program using TextBlob to perform sentiment analysis on the given paragraph and print polarity and subjectivity scores.**

# %%
# Write your solution here

# %% [markdown]
# ## Question 7
#
# **Given the sample paragraph, perform string tokenization and frequency distribution using Python and NLTK.**

# %%
# Write your solution here

# %% [markdown]
# ## Question 8
#
# **Implement a basic LSTM model in Keras for the provided dummy text classification dataset.**

# %%
# Write your solution here

# %% [markdown]
# ## Question 9
#
# **Using spaCy, build an NLP pipeline with tokenization, lemmatization, and named entity recognition for the given paragraph.**

# %%
# Write your solution here

# %% [markdown]
# ## Question 10
#
# **Explain how to leverage LSTM or GRU with spaCy or Stanford NLP for a mental health chatbot, including preprocessing, architecture, and ethics.**

# %% [markdown]
# ### Answer
