# %% [markdown]
# # Useful NLP Libraries & Networks Assignment
#
# Template notebook.

# %% [markdown]
# ## Question 1
#
# (Refer to assignment PDF for question.)

# %% [markdown]
# **Answer:**
#
# _To be completed._

# %% [markdown]
# ## Question 2
#
# (Refer to assignment PDF for question.)

# %% [markdown]
# **Answer:**
#
# _To be completed._

# %% [markdown]
# ## Question 3
#
# (Refer to assignment PDF for question.)

# %% [markdown]
# **Answer:**
#
# _To be completed._

# %% [markdown]
# ## Question 4
#
# (Refer to assignment PDF for question.)

# %% [markdown]
# **Answer:**
#
# _To be completed._

# %% [markdown]
# ## Question 5
#
# (Refer to assignment PDF for question.)

# %% [markdown]
# **Answer:**
#
# _To be completed._

# %% [markdown]
# ## Question 6
#
# (Refer to assignment PDF for question.)

# %%
# Solution code goes here

# %% [markdown]
# ## Question 7
#
# (Refer to assignment PDF for question.)

# %%
# Solution code goes here

# %% [markdown]
# ## Question 8
#
# (Refer to assignment PDF for question.)

# %%
# Solution code goes here

# %% [markdown]
# ## Question 9
#
# (Refer to assignment PDF for question.)

# %%
# Solution code goes here

# %% [markdown]
# ## Question 10
#
# (Refer to assignment PDF for question.)

# %% [markdown]
# **Answer:**
#
# _To be completed._
